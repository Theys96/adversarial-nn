# %% [markdown]
# # Adverserial learning at scale - Kurakin et al
# Here we give an insight into several adverserial attack methods that were studied in the paper by Kurakin (2017). We show the performance of the methods in preventing the correct classification of a simple example image. As model we used the pretrained ResNet-50 model for classification of the ImageNet dataset.
#
# Similar to Kurakin (2017), we will use the following notations:
#
# $$
# \begin{align}
# \boldsymbol{X}&\quad \text{the original input image}\\
# \boldsymbol{X}^{adv}&\quad \text{the adverserial image which is computed by the advererial attack methods}\\
# y&\quad \text{classification label}\\
# \epsilon &\quad \text{The size of the perturbation, expressed in terms of pixel values} \in [0,\, 255]\\
# J(\boldsymbol{X}, y_{true})&\quad \text{cost function used to train the model}\\
# Clip_{\boldsymbol{X},\epsilon}(\boldsymbol{A}) &\quad \text{element wise clipping of } \boldsymbol{A} \text{, with } A_{i,j} \text{ clipped to the range } [\boldsymbol{X}_{i,j} - \epsilon, \boldsymbol{X}_{i,j} + \epsilon]
# \end{align}
# $$

# %% [markdown]
# We start by importing the prerequisites

# %%
from PIL import Image
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np

import json
import torch
import torch.nn as nn
from torchvision.models import resnet50
from torch.autograd import Variable
import torch.nn.functional as F

# %% [markdown]
# Now we can set and preprocess the example image, which we will be using in this notebook.

# %%
# Read the example image
image = Image.open("../../data/pictures/kopje.jpg")
# Reel free to change kopje.jpg to any other image, such as pig.jpg. 
# The parameters might need retuning in that case
#image = Image.open("pig.jpg")

# Standard normalization values for ImageNet images, 
# obtained from https://github.com/pytorch/examples/blob/master/imagenet/main.py
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]


# Resize to 224, convert to PyTorch Tensor and perform normalizationa
preprocess = transforms.Compose([
   transforms.Resize(224),
   transforms.ToTensor(),
   transforms.Normalize(mean, std)
])

# Add batch dimension
image_tensor = preprocess(image).unsqueeze(0)

image_variable = Variable(image_tensor, requires_grad=True)

# %% [markdown]
# We define a function which will be used to display the image, along with the predicted label and corresponding probability.

# %%
def show_image(image_variable, pred_label, prob):
    # remove batch dimension
    img = image_variable.squeeze(0)
    
    # Undo normalizations
    img = img.mul(torch.FloatTensor(std).view(3,1,1)).add(torch.FloatTensor(mean).view(3,1,1)).detach().numpy()

    # Convert C X H X W -->  H X W X C
    img = np.transpose(img, (1,2,0))   
    img = np.clip(img, 0, 1)
    
    figure, ax = plt.subplots(1,1, figsize=(4,4))
    
    ax.imshow(img)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])

    
    ax.text(0.5, -0.2,
            'Prediction: {}\n Probability: {:.4f}'.format(pred_label, prob),
            size=12, ha="center", transform=ax.transAxes)
    
    plt.show()

# %% [markdown]
# Now we can load our pre-trained model, and the ImagNet labels corresponding to the classification indices

# %%
# Load pre-trained ResNet50, and put model into evaluation mode 
model = resnet50(pretrained=True)
model.eval();

# %%
# Load labels corresponding to ImageNet class indices
with open("../../data/models/imagenet_class_index.json") as f:
    imagenet_classes = {int(i):x[1] for i,x in json.load(f).items()}

# %% [markdown]
# # Original model performance
# First, we show the performance of the model on the original image, to make sure it works correctly. The image is correctly classified as 'espresso' with high probability.

# %%
pred = model(image_variable)

pred_label = imagenet_classes[pred.max(dim=1)[1].item()]
probs = F.softmax(pred, dim=1)
prob = torch.max(probs.data, 1)[0][0] * 100

# plot image
show_image(image_variable, pred_label, prob)

# %% [markdown]
# # Fast Gradient Sign Method
# Now we apply the Fast Gradient Sign Method (FGSM). The FGSM method was first proposed by Goodfellow (2015). It is a one-step method, that is easy to compute. The method aims to find perturbations that maximize the the value loss function $J(\boldsymbol{X},y)$. The computation of the adverserial  image is done as follows:
#
# $$
# \boldsymbol{X}^{adv} = \boldsymbol{X} + \epsilon\, \text{sign}{\nabla_x J(\boldsymbol{X}, y_{true})}
# $$
#
# Here follows the implementation in pytorch:

# %%
y_true = 967
epsilon = 2/255

pred = model(image_variable)

model.zero_grad()

loss = nn.CrossEntropyLoss()(pred, torch.LongTensor([y_true]))

loss.backward(retain_graph=True)

perturbed_image = image_variable + epsilon * image_variable.grad.data.sign()

# %% [markdown]
# We will now obtain the predicted label and probability. Next, we will show the perturbed image.

# %%
pred = model(perturbed_image)
pred_label = imagenet_classes[pred.max(dim=1)[1].item()]
probs = F.softmax(pred_perturbed, dim=1)
prob = torch.max(probs.data, 1)[0][0] * 100

# plot image
show_image(perturbed_image, pred_label, prob)

# %% [markdown]
# As can be seen from the result above, the adverserial image appears exactly similar to the original input image. However it is now classified as 'consomme' instead of 'espresso', with a much higher probability. It seems that the attack is working!

# %%
# reset the gradients
image_variable.grad.data.zero_();

# %% [markdown]
# # One step least-likely class
# The next method we implement is the one step least-likely class method. The method is a variation of the FGSM method, that aims to maximize the probability $P(y_{target} | \boldsymbol{X})$ towards a target class $y_{target}$ that is not likely for the current input. In this single-step method, the adverserial image $\boldsymbol{X}^{adv}$ is computed as follows:
# $$
# \boldsymbol{X}^{adv} = \boldsymbol{X} - \epsilon\, \text{sign}{\nabla_x J(\boldsymbol{X}, y_{LL})}
# $$
# Here, $y_{LL} = \arg \min_y p(y | \boldsymbol{X})$ represents the least likely class. Now follows our implementation:

# %%
# find least likely class
pred = model(image_variable)
y_target = torch.argmin(pred).item()
print('least likely class: {}'.format(imagenet_classes[y_target]))

epsilon = 2/255

pred = model(image_variable)

model.zero_grad()

loss = nn.CrossEntropyLoss()(pred, torch.LongTensor([y_target]))

loss.backward(retain_graph=True)

perturbed_image = image_variable - epsilon * image_variable.grad.data.sign()
# Out:
# least likely class: dam

# %% [markdown]
# We will now obtain the predicted label and probability. Next, we will show the perturbed image.

# %%
pred_perturbed = model(perturbed_image)

pred_label = imagenet_classes[pred_perturbed.max(dim=1)[1].item()]
probs = F.softmax(pred_perturbed, dim=1)
prob = torch.max(probs.data, 1)[0][0] * 100

# plot image
show_image(perturbed_image, pred_label, prob)

# %%
# reset the gradients
image_variable.grad.data.zero_();

# %% [markdown]
# # Basic iterative method attack
#
# Iterative methods apply many gradient updates. The Basic iterative method is an extension of the FGSM method. The method applies the FGSM method multiple times with small step size. In order to prevent an end result with too much noise, the $Clip_{\boldsymbol{X},\epsilon}$ function is applied. This leads to the following formula:
#
# $$
# \boldsymbol{X}^{adv}_0 = \boldsymbol{X},\quad \boldsymbol{X}^{adv}_{N+1} = Clip_{\boldsymbol{X},\epsilon} \{ \boldsymbol{X}^{adv}_{N} + \alpha \, \text{sign}\nabla_x J(\boldsymbol{X}^{adv}_{N}, y_{true}) \}
# $$
#
# Here $\alpha$ represents the weight of the perturbation in each step. Now follows the implementation in python code:

# %%
y_true = 967
epsilon = 2/255
alpha = 1
num_steps = 10

for i in range(num_steps):
    
    pred = model(image_variable)

    loss = nn.CrossEntropyLoss()(pred, torch.LongTensor([y_true]))
    
    loss.backward()
        
    x_adv_temp = image_variable.data + alpha * image_variable.grad.data.sign()
    
    total_grad = x_adv_temp - image_tensor
    
    image_variable.data = image_tensor + total_grad.data.clamp(-epsilon, epsilon)

# %%
pred = model(image_variable)

pred_label = imagenet_classes[pred.max(dim=1)[1].item()]
probs = F.softmax(pred, dim=1)
prob = torch.max(probs.data, 1)[0][0] * 100

# plot image
show_image(image_variable, pred_label, prob)

# %% [markdown]
# We can see that the basic iterative method (BIM) is even more effective than the FGSM method, due to the higher probability. This can be expected, since the BIM method is essentially multiple FGSM methods applied after each other.

# %%
# reset the gradients
image_variable.grad.data.zero_();

# %% [markdown]
# # Iterative leasy-likely class method
# An iterative method that applies the one-step least-likely class method multiple times:
# $$
# \boldsymbol{X}^{adv}_0 = \boldsymbol{X},\quad \boldsymbol{X}^{adv}_{N+1} = Clip_{\boldsymbol{X},\epsilon} \{ \boldsymbol{X}^{adv}_{N} - \alpha \, \text{sign}\nabla_x J(\boldsymbol{X}^{adv}_{N}, y_{LL})\}
# $$

# %%
# find least likely class
pred = model(image_variable)
y_target = torch.argmin(pred).item()
print('least likely class: {}'.format(imagenet_classes[y_target]))

epsilon = 0.3
alpha = 0.025
num_steps = 10

for i in range(num_steps):
    
    pred = model(image_variable)

    loss = nn.CrossEntropyLoss()(pred, torch.LongTensor([y_target]))
    
    loss.backward()
        
    x_adv_temp = image_variable.data - alpha * image_variable.grad.data.sign()
    
    total_grad = x_adv_temp - image_tensor
    
    image_variable.data = image_tensor + total_grad.data.clamp(-epsilon, epsilon)
# Out:
# least likely class: catamaran

# %%
pred = model(image_variable)

pred_label = imagenet_classes[pred.max(dim=1)[1].item()]
probs = F.softmax(pred, dim=1)
prob = torch.max(probs.data, 1)[0][0] * 100

# plot image
show_image(image_variable, pred_label, prob)

# %% [markdown]
# As can be observed from the image above, the Iterative Least Likely Class method is able to effectively change the input image such that it will now predict the least likely class label instead of the correct label.

# %% [markdown]
# # Performance on adverserial trained model

# %% [markdown]
# Because of the high computational requirements of training ResNet-50 with the imagenet dataset, we chose to assess the effect of adverserial training using the MNIST dataset. Please see the file FGSM-mnist.ipynb

# %% [markdown]
# # References

# %% [markdown]
# Goodfellow, I. J., Shlens, J., & Szegedy, C. (2015). Explaining and Harnessing Adversarial Examples. ArXiv:1412.6572 [Cs, Stat]. http://arxiv.org/abs/1412.6572
#
# Kurakin, A., Goodfellow, I., & Bengio, S. (2017). Adversarial Machine Learning at Scale. ArXiv:1611.01236 [Cs, Stat]. http://arxiv.org/abs/1611.01236
#
# Madry, Z. K. and A. (n.d.). Adversarial Robustness—Theory and Practice. Retrieved November 8, 2021, from http://adversarial-ml-tutorial.org/
